# %%
import Pkg; Pkg.add("Flux")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed PrettyPrint ───────── v0.2.0
#    Installed ZygoteRules ───────── v0.2.7
#    Installed RealDot ───────────── v0.1.0
#    Installed Accessors ─────────── v0.1.42
#    Installed InitialValues ─────── v0.3.1
#    Installed MLUtils ───────────── v0.4.8
#    Installed ContextVariablesX ─── v0.1.3
#    Installed ShowCases ─────────── v0.1.0
#    Installed IRTools ───────────── v0.4.14
#    Installed MLCore ────────────── v1.0.0
#    Installed DefineSingletons ──── v0.1.2
#    Installed FLoopsBase ────────── v0.1.1
#    Installed MicroCollections ──── v0.2.0
#    Installed ProgressLogging ───── v0.1.4
#    Installed OneHotArrays ──────── v0.2.10
#    Installed Zygote ────────────── v0.7.10
#    Installed NameResolution ────── v0.1.5
#    Installed SparseInverseSubset ─ v0.1.2
#    Installed CompositionsBase ──── v0.1.2
#    Installed JuliaVariables ────── v0.2.4
#    Installed BangBang ──────────── v0.4.4
#    Installed ChainRules ────────── v1.72.5
#    Installed FLoops ────────────── v0.2.2
#    Installed MLStyle ───────────── v0.4.17
#    Installed Flux ──────────────── v0.16.4
#    Installed SplittablesBase ───── v0.1.15
#    Installed Baselet ───────────── v0.1.1
#    Installed Transducers ───────── v0.4.84
#     Updating `~/.julia/environments/v1.10/Project.toml`
#   [587475ba] + Flux v0.16.4
#     Updating `~/.julia/environments/v1.10/Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.42
#   [198e06fe] + BangBang v0.4.4
#   [9718e550] + Baselet v0.1.1
#   [082447d4] + ChainRules v1.72.5
#   [a33af91c] + CompositionsBase v0.1.2
#   [6add18c4] + ContextVariablesX v0.1.3
#   [244e2a9f] + DefineSingletons v0.1.2
#   [cc61a311] + FLoops v0.2.2
#   [b9860ae5] + FLoopsBase v0.1.1
#   [587475ba] + Flux v0.16.4
#   [7869d1d1] + IRTools v0.4.14
#   [22cec73e] + InitialValues v0.3.1
#   [b14d175d] + JuliaVariables v0.2.4
#   [c2834f40] + MLCore v1.0.0
#   [d8e11817] + MLStyle v0.4.17
#   [f1d291b0] + MLUtils v0.4.8
#   [128add7d] + MicroCollections v0.2.0
#   [71a1bf82] + NameResolution v0.1.5
#   [0b1bfda6] + OneHotArrays v0.2.10
#   [8162dcfd] + PrettyPrint v0.2.0
#   [33c8b6b6] + ProgressLogging v0.1.4
#   [c1ae055f] + RealDot v0.1.0
#   [605ecd9f] + ShowCases v0.1.0
#   [dc90abb0] + SparseInverseSubset v0.1.2
#   [171d559e] + SplittablesBase v0.1.15
#   [28d57a85] + Transducers v0.4.84
#   [e88e6eb3] + Zygote v0.7.10
#   [700de1a5] + ZygoteRules v0.2.7
# Precompiling packages...
#    3893.8 ms  ✓ InitialValues
#    2411.8 ms  ✓ PrettyPrint
#    3432.8 ms  ✓ ShowCases
#     995.8 ms  ✓ CompositionsBase
#    1076.8 ms  ✓ RealDot
#    1107.7 ms  ✓ DefineSingletons
#    1208.9 ms  ✓ ContextVariablesX
#    1394.4 ms  ✓ ProgressLogging
#    5248.7 ms  ✓ IRTools
#    4510.4 ms  ✓ Baselet
#    3049.8 ms  ✓ ZygoteRules
#    1628.2 ms  ✓ SparseInverseSubset
#    2379.4 ms  ✓ MLCore
#    2269.8 ms  ✓ SplittablesBase
#    3215.9 ms  ✓ OneHotArrays
#    1290.7 ms  ✓ NameResolution
#    1049.1 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    1461.7 ms  ✓ FLoopsBase
#   16742.9 ms  ✓ MLDataDevices → MLDataDevicesCUDAExt
#    4581.3 ms  ✓ MLDataDevices → MLDataDevicesOneHotArraysExt
#   15851.1 ms  ✓ ChainRules
#    7187.9 ms  ✓ Accessors
#   89014.0 ms  ✓ MLStyle
#    2283.2 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesExt
#    2348.6 ms  ✓ MLDataDevices → MLDataDevicesChainRulesExt
#    1954.8 ms  ✓ Accessors → LinearAlgebraExt
#   69670.9 ms  ✓ Reactant → ReactantOneHotArraysExt
#    1409.7 ms  ✓ Accessors → StructArraysExt
#    7954.0 ms  ✓ JuliaVariables
#    1656.6 ms  ✓ Accessors → TestExt
#    1572.5 ms  ✓ Accessors → IntervalSetsExt
#    2555.9 ms  ✓ Accessors → UnitfulExt
#    2319.7 ms  ✓ Accessors → StaticArraysExt
#    2369.5 ms  ✓ BangBang
#    1931.3 ms  ✓ BangBang → BangBangChainRulesCoreExt
#    2314.6 ms  ✓ BangBang → BangBangStaticArraysExt
#    1725.9 ms  ✓ BangBang → BangBangTablesExt
#    1868.4 ms  ✓ MicroCollections
#    1588.1 ms  ✓ BangBang → BangBangStructArraysExt
#    5312.9 ms  ✓ BangBang → BangBangDataFramesExt
#    6365.4 ms  ✓ Transducers
#    2713.1 ms  ✓ Transducers → TransducersAdaptExt
#    5583.6 ms  ✓ Transducers → TransducersDataFramesExt
#    7654.4 ms  ✓ FLoops
#   14322.4 ms  ✓ MLUtils
#    4039.9 ms  ✓ MLDataDevices → MLDataDevicesMLUtilsExt
#    4005.5 ms  ✓ Lux → LuxMLUtilsExt
#  119954.4 ms  ✓ Zygote
#    3173.1 ms  ✓ MLDataDevices → MLDataDevicesZygoteExt
#    4659.1 ms  ✓ Zygote → ZygoteColorsExt
#    6165.1 ms  ✓ Lux → LuxZygoteExt
#   11296.8 ms  ✓ Flux
#    1605.3 ms  ✓ Flux → FluxCUDAExt
#    7260.6 ms  ✓ Lux → LuxFluxExt
#   32108.8 ms  ✓ Flux → FluxEnzymeExt
#   55 dependencies successfully precompiled in 220 seconds. 462 already precompiled.
#   1 dependency had output during precompilation:
# ┌ Reactant → ReactantOneHotArraysExt
# │  2025-06-18 04:49:02.647693: I external/xla/xla/pjrt/pjrt_api.cc:93] PJRT_Api is set for device type tpu
# └

# %%
using Flux

# Define input and target data
X = [1.0, 2.0, 3.0]  # Input data
y = [2.0, 4.0, 6.0]  # Target outputs (y = 2x)

# Reshape data for Flux (each column is a sample)
X_train = reshape(X, 1, :)  # 1×3 matrix
y_train = reshape(y, 1, :)  # 1×3 matrix

# Define a simple linear model (single neuron, no bias for cleaner y=2x learning)
model = Dense(1 => 1, identity; bias=false)

# Define loss function that takes model as parameter
function loss_fn(m)
    return Flux.mse(m(X_train), y_train)
end

# Define optimizer with higher learning rate
opt = Flux.setup(Adam(0.1), model)

# Training parameters
epochs = 1000

# Training loop
println("Training the neural network...")
println("Initial weight: ", model.weight[1])

for epoch in 1:epochs
    # Compute gradients - pass the loss function and model
    grads = Flux.gradient(loss_fn, model)

    # Update parameters
    Flux.update!(opt, model, grads[1])

    # Print progress every 100 epochs
    if epoch % 100 == 0
        current_loss = loss_fn(model)
        println("Epoch $epoch: Loss = $(round(current_loss, digits=6)), Weight = $(round(model.weight[1], digits=4))")
    end
end

# Display final results
println("\n" * "="^50)
println("Training completed!")
println("Final learned weight: ", round(model.weight[1], digits=4))
println("Target weight: 2.0")
println("Final loss: ", round(loss_fn(model), digits=6))

# Test the model
println("\nTesting the model:")
for i in 1:length(X)
    input_val = X[i]
    predicted = model([input_val])[1]
    actual = y[i]
    println("Input: $input_val, Predicted: $(round(predicted, digits=4)), Actual: $actual")
end

# Verify with new data point
test_input = 5.0
test_prediction = model([test_input])[1]
expected_output = 2.0 * test_input
println("\nNew test:")
println("Input: $test_input, Predicted: $(round(test_prediction, digits=4)), Expected: $expected_output")
# Out:
# Training the neural network...
# Initial weight: -1.4703591
# Epoch 100: Loss = 0.000644, Weight = 1.9883
# Epoch 200: Loss = 0.0, Weight = 2.0
# Epoch 300: Loss = 0.0, Weight = 2.0
# Epoch 400: Loss = 0.0, Weight = 2.0
# Epoch 500: Loss = 0.0, Weight = 2.0
# Epoch 600: Loss = 0.0, Weight = 2.0
# Epoch 700: Loss = 0.0, Weight = 2.0
# Epoch 800: Loss = 0.0, Weight = 2.0
# Epoch 900: Loss = 0.0, Weight = 2.0
# Epoch 1000: Loss = 0.0, Weight = 2.0
#
# ==================================================
# Training completed!
# Final learned weight: 2.0
# Target weight: 2.0
# Final loss: 0.0
#
# Testing the model:
# Input: 1.0, Predicted: 2.0, Actual: 2.0
# Input: 2.0, Predicted: 4.0, Actual: 4.0
# Input: 3.0, Predicted: 6.0, Actual: 6.0
#
# New test:
# Input: 5.0, Predicted: 10.0, Expected: 10.0
